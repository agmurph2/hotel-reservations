# %%
import pandas as pd
hotels = pd.read_csv(r"C:\Users\augie\Downloads\archive\Hotel Reservations.csv")
hotels
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
#Basics
hotels.info()
hotels.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %%
#Data Preperation - Cleaning & Normalization
hotels.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
#One-hot encode for categorical, standardize numerical
# Drop useless ID column
hotels = hotels.drop('Booking_ID', axis=1)

# Encode target manually
hotels['booking_status'] = hotels['booking_status'].map({
    'Not_Canceled': 0,
    'Canceled': 1
})

y = hotels['booking_status']

# One-hot encode X
X = pd.get_dummies(
    hotels.drop('booking_status', axis=1),
    drop_first=True
)

# %%
from sklearn.preprocessing import StandardScaler
num_cols = X.select_dtypes(include=['int64', 'float64']).columns

scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])

# %%
#train test split using 20% as the test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression(max_iter=3000)

# fit the model with training data
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=3000)

# %%
# Interpret coefficient, which is saved in .coef attribute
coef = pd.DataFrame(logreg.coef_[0], index = X.columns,columns=['Coefficients'])
coef.sort_values(by=['Coefficients'])
# Out:
#                                       Coefficients
# room_type_reserved_Room_Type 7           -1.481068
# market_segment_type_Offline              -1.395919
# no_of_special_requests                   -1.168143
# market_segment_type_Complementary        -1.136959
# room_type_reserved_Room_Type 6           -1.030065
# room_type_reserved_Room_Type 5           -0.765121
# market_segment_type_Corporate            -0.549414
# room_type_reserved_Room_Type 2           -0.332047
# repeated_guest                           -0.302736
# room_type_reserved_Room_Type 4           -0.282322
# required_car_parking_space               -0.272333
# no_of_previous_bookings_not_canceled     -0.176645
# arrival_month                            -0.122644
# room_type_reserved_Room_Type 3           -0.013681
# arrival_date                              0.019962
# no_of_adults                              0.044962
# no_of_week_nights                         0.045092
# ...

# %%
# coefficient is intepreted as with one unit change in X, how many unit will change in log(odds). We need to take exponentiate
# of the original coeffient and interpret it in terms of odds
import numpy as np
df = pd.DataFrame(np.exp(logreg.coef_[0]), index = X.columns,columns = ['Odds'])
df
df.sort_values(by=['Odds'])
# Out:
#                                           Odds
# room_type_reserved_Room_Type 7        0.227395
# market_segment_type_Offline           0.247605
# no_of_special_requests                0.310944
# market_segment_type_Complementary     0.320793
# room_type_reserved_Room_Type 6        0.356984
# room_type_reserved_Room_Type 5        0.465277
# market_segment_type_Corporate         0.577288
# room_type_reserved_Room_Type 2        0.717453
# repeated_guest                        0.738794
# room_type_reserved_Room_Type 4        0.754030
# required_car_parking_space            0.761600
# no_of_previous_bookings_not_canceled  0.838077
# arrival_month                         0.884579
# room_type_reserved_Room_Type 3        0.986412
# arrival_date                          1.020162
# no_of_adults                          1.045988
# no_of_week_nights                     1.046124
# no_of_children                        1.064854
# no_of_previous_cancellations          1.089358
# ...

# %%
#  Get the top 5 most important features
top_5_features = df.sort_values(by=['Odds'], ascending=False).head(5)
print("\nTop 5 most significant features:")
print(top_5_features)

# Get the bottom 5 features
bottom_5_features = df.sort_values(by=['Odds']).head(5)
print("\nBottom 5 most significant features:")
print(bottom_5_features)
# Out:
# Top 5 most significant features:
#                                     Odds
# lead_time                       3.834800
# avg_price_per_room              1.923101
# market_segment_type_Online      1.447749
# type_of_meal_plan_Not Selected  1.244686
# arrival_year                    1.190297
#
# Bottom 5 most significant features:
#                                        Odds
# room_type_reserved_Room_Type 7     0.227395
# market_segment_type_Offline        0.247605
# no_of_special_requests             0.310944
# market_segment_type_Complementary  0.320793
# room_type_reserved_Room_Type 6     0.356984

# %%
#Evaluation
y_pred = logreg.predict(X_test)
y_pred

#accuracy as one evaluation metrics
from sklearn import metrics
print("Accuracy on the training set::{:.3f}".format(logreg.score(X_train, y_train)))
print("Accuracy on the test set::{:.3f}".format(metrics.accuracy_score(y_test, y_pred)))
# Out:
# Accuracy on the training set::0.804
# Accuracy on the test set::0.803

# %%
# interpret confuison matrix
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(y_test, y_pred, labels=logreg.classes_)
dsp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=logreg.classes_)
dsp.plot()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      4854
#            1       0.74      0.62      0.68      2401
#
#     accuracy                           0.80      7255
#    macro avg       0.78      0.76      0.77      7255
# weighted avg       0.80      0.80      0.80      7255

# %%
from sklearn.metrics import accuracy_score

y_pred = logreg.predict(X_test)
print("Accuracy on training set: {:.3f}".format(logreg.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(accuracy_score(y_pred, y_test)))
# Out:
# Accuracy on training set: 0.804
# Accuracy on test set: 0.803

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get predicted probabilities for the positive class (1 = canceled)
y_prob = logreg.predict_proba(X_test)[:, 1]

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# Compute AUC
auc_score = roc_auc_score(y_test, y_prob)
print("AUC Score:", auc_score)

# Plot ROC
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"AUC = {auc_score:.3f}")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')  # baseline
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()
# Out:
# AUC Score: 0.8618804450212768

# %%
#Ensemble method - random forest
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=300,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
y_prob_rf = rf.predict_proba(X_test)[:, 1]

# %%
print(classification_report(y_test, y_pred_rf))
print("AUC:", roc_auc_score(y_test, y_prob_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      4854
#            1       0.89      0.81      0.85      2401
#
#     accuracy                           0.90      7255
#    macro avg       0.90      0.88      0.89      7255
# weighted avg       0.90      0.90      0.90      7255
#
# AUC: 0.9571022803813888

# %%
from sklearn.metrics import accuracy_score

y_pred = rf.predict(X_test)
print("Accuracy on training set: {:.3f}".format(rf.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(accuracy_score(y_pred_rf, y_test)))
# Out:
# Accuracy on training set: 0.994
# Accuracy on test set: 0.905

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test, y_prob_rf)
auc_rf = roc_auc_score(y_test, y_prob_rf)

plt.plot(fpr, tpr, label=f"Random Forest (AUC={auc_rf:.3f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

cv_auc = cross_val_score(
    rf,
    X,
    y,
    cv=skf,
    scoring='roc_auc',
    n_jobs=-1
)

print("CV AUC Scores:", cv_auc)
print("Mean AUC:", cv_auc.mean())
# Out:
# CV AUC Scores: [0.95413193 0.95952559 0.95316708 0.95641391 0.95872361]
# Mean AUC: 0.9563924244627386

# %%
#Hyperparameter tuning
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [200, 300, 500],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
}

grid = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid,
    cv=3,
    scoring='roc_auc',
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("Best Params:", grid.best_params_)
print("Best AUC:", grid.best_score_)
# Out:
# Best Params: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
# Best AUC: 0.9516769073970588

# %%
best_rf = RandomForestClassifier(
    n_estimators=grid.best_params_['n_estimators'],
    max_depth=grid.best_params_['max_depth'],
    min_samples_split=grid.best_params_['min_samples_split'],
    min_samples_leaf=grid.best_params_['min_samples_leaf'],
    random_state=42,
    n_jobs=-1
)

best_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=500, n_jobs=-1,
#                        random_state=42)

# %%
from sklearn.metrics import classification_report, roc_auc_score

y_pred_best = best_rf.predict(X_test)
y_prob_best = best_rf.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred_best))
print("Recall:", recall_score(y_test, y_pred_best))
print("AUC:", roc_auc_score(y_test, y_prob_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      4854
#            1       0.89      0.81      0.85      2401
#
#     accuracy                           0.91      7255
#    macro avg       0.90      0.88      0.89      7255
# weighted avg       0.90      0.91      0.90      7255
#
# Recall: 0.8096626405664307
# AUC: 0.9569368500660776

# %%
y_pred = best_rf.predict(X_test)
print("Accuracy on training set: {:.3f}".format(best_rf.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(accuracy_score(y_pred_best, y_test)))
# Out:
# Accuracy on training set: 0.955
# Accuracy on test set: 0.905

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test, y_prob_best)

plt.plot(fpr, tpr, label=f"Optimized RF (AUC={roc_auc_score(y_test, y_prob_best):.3f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.title("ROC Curve - Optimized Random Forest")
plt.show()

# %%
import pandas as pd
import numpy as np

importances = best_rf.feature_importances_
feat_names = X.columns

importance_df = pd.DataFrame({
    'Feature': feat_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

importance_df.head(20)
# Out:
#                                  Feature  Importance
# 5                              lead_time    0.329046
# 12                    avg_price_per_room    0.148479
# 13                no_of_special_requests    0.121435
# 7                          arrival_month    0.077655
# 8                           arrival_date    0.073030
# 3                      no_of_week_nights    0.046087
# 26            market_segment_type_Online    0.034419
# 2                   no_of_weekend_nights    0.034022
# 6                           arrival_year    0.029525
# 0                           no_of_adults    0.024048
# 25           market_segment_type_Offline    0.019727
# 14         type_of_meal_plan_Meal Plan 2    0.012315
# 16        type_of_meal_plan_Not Selected    0.008327
# 19        room_type_reserved_Room_Type 4    0.008230
# 4             required_car_parking_space    0.007133
# 1                         no_of_children    0.006885
# 24         market_segment_type_Corporate    0.006411
# ...

# %%
# interpret confuison matrix
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

cm = confusion_matrix(y_test, y_pred_best, labels=logreg.classes_)
dsp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_rf.classes_)
dsp.plot()

# %% [markdown]
# Then I optimized hyperparmeters to prioritize recall

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [200, 300, 500],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
}

grid_recall = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid,
    cv=skf,
    scoring='recall',
    n_jobs=-1
)

grid_reacll.fit(X_train, y_train)

print("Best Params:", grid_recall.best_params_)
print("Best AUC:", grid_recall.best_score_)
# Out:
# Best Params: {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
# Best AUC: 0.8113657696251465

# %%
from sklearn.ensemble import RandomForestClassifier

recall_rf = RandomForestClassifier(
    max_depth=30,
    min_samples_leaf=1,
    min_samples_split=2,
    n_estimators=500,
    random_state=42,
    n_jobs=-1
)

recall_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=30, n_estimators=500, n_jobs=-1,
#                        random_state=42)

# %%
from sklearn.metrics import classification_report, roc_auc_score, recall_score

y_pred_recall = recall_rf.predict(X_test)
y_prob_recall = recall_rf.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred_recall))
print("Recall:", recall_score(y_test, y_pred_recall))
print("AUC:", roc_auc_score(y_test, y_prob_recall))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93      4854
#            1       0.90      0.81      0.85      2401
#
#     accuracy                           0.91      7255
#    macro avg       0.90      0.88      0.89      7255
# weighted avg       0.91      0.91      0.90      7255
#
# Recall: 0.806747188671387
# AUC: 0.9578902623838063

# %% [markdown]
# The difference in recall when we optimize for it vs AUC is negligible and statistical noise, so we should proceed with the model that optimizes AUC, best_rf
